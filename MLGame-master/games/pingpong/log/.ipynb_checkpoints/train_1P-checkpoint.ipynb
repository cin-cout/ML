# %%
# beta 8.0.1
import pickle
import os.path
import numpy as np
dirs=os.listdir(os.getcwd())
data=[]
for i in dirs:
    
    if 'pickle' and 'ml' in i:
        with open(i, 'rb') as f:
            data.append(pickle.load(f))
        

print(data[0].keys())
# Out:
# dict_keys(['record_format_version', 'ml_1P', 'ml_2P'])

# %%
for i in range(0,len(data)):
    data[i]['ml_1P'].keys()

# %%
    data[i]['ml_1P']['scene_info']
# Out:
# [{'frame': 0,
#   'status': 'GAME_ALIVE',
#   'ball': (98, 415),
#   'ball_speed': (0, 0),
#   'platform_1P': (80, 420),
#   'platform_2P': (80, 50),
#   'blocker': (180, 240)},
#  {'frame': 1,
#   'status': 'GAME_ALIVE',
#   'ball': (98, 415),
#   'ball_speed': (-7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (80, 50),
#   'blocker': (170, 240)},
#  {'frame': 2,
#   'status': 'GAME_ALIVE',
#   'ball': (91, 408),
#   'ball_speed': (-7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (85, 50),
#   'blocker': (165, 240)},
#  {'frame': 3,
#   'status': 'GAME_ALIVE',
#   'ball': (84, 401),
#   'ball_speed': (-7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (90, 50),
#   'blocker': (160, 240)},
#  {'frame': 4,
#   'status': 'GAME_ALIVE',
#   'ball': (77, 394),
#   'ball_speed': (-7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (95, 50),
#   'blocker': (155, 240)},
#  {'frame': 5,
#   'status': 'GAME_ALIVE',
#   'ball': (70, 387),
#   'ball_speed': (-7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (100, 50),
#   'blocker': (150, 240)},
#  {'frame': 6,
#   'status': 'GAME_ALIVE',
#   'ball': (63, 380),
#   'ball_speed': (-7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (105, 50),
#   'blocker': (145, 240)},
#  {'frame': 7,
#   'status': 'GAME_ALIVE',
#   'ball': (56, 373),
#   'ball_speed': (-7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (110, 50),
#   'blocker': (140, 240)},
#  {'frame': 8,
#   'status': 'GAME_ALIVE',
#   'ball': (49, 366),
#   'ball_speed': (-7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (115, 50),
#   'blocker': (135, 240)},
#  {'frame': 9,
#   'status': 'GAME_ALIVE',
#   'ball': (42, 359),
#   'ball_speed': (-7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (120, 50),
#   'blocker': (130, 240)},
#  {'frame': 10,
#   'status': 'GAME_ALIVE',
#   'ball': (35, 352),
#   'ball_speed': (-7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (125, 50),
#   'blocker': (125, 240)},
#  {'frame': 11,
#   'status': 'GAME_ALIVE',
#   'ball': (28, 345),
#   'ball_speed': (-7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (130, 50),
#   'blocker': (120, 240)},
#  {'frame': 12,
#   'status': 'GAME_ALIVE',
#   'ball': (21, 338),
#   'ball_speed': (-7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (135, 50),
#   'blocker': (115, 240)},
#  {'frame': 13,
#   'status': 'GAME_ALIVE',
#   'ball': (14, 331),
#   'ball_speed': (-7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (135, 50),
#   'blocker': (110, 240)},
#  {'frame': 14,
#   'status': 'GAME_ALIVE',
#   'ball': (7, 324),
#   'ball_speed': (-7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (135, 50),
#   'blocker': (105, 240)},
#  {'frame': 15,
#   'status': 'GAME_ALIVE',
#   'ball': (0, 317),
#   'ball_speed': (7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (135, 50),
#   'blocker': (100, 240)},
#  {'frame': 16,
#   'status': 'GAME_ALIVE',
#   'ball': (7, 310),
#   'ball_speed': (7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (135, 50),
#   'blocker': (95, 240)},
#  {'frame': 17,
#   'status': 'GAME_ALIVE',
#   'ball': (14, 303),
#   'ball_speed': (7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (135, 50),
#   'blocker': (90, 240)},
#  {'frame': 18,
#   'status': 'GAME_ALIVE',
#   'ball': (21, 296),
#   'ball_speed': (7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (135, 50),
#   'blocker': (85, 240)},
#  {'frame': 19,
#   'status': 'GAME_ALIVE',
#   'ball': (28, 289),
#   'ball_speed': (7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (135, 50),
#   'blocker': (80, 240)},
#  {'frame': 20,
#   'status': 'GAME_ALIVE',
#   'ball': (35, 282),
#   'ball_speed': (7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (135, 50),
#   'blocker': (75, 240)},
#  {'frame': 21,
#   'status': 'GAME_ALIVE',
#   'ball': (42, 275),
#   'ball_speed': (7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (135, 50),
#   'blocker': (70, 240)},
#  {'frame': 22,
#   'status': 'GAME_ALIVE',
#   'ball': (49, 268),
#   'ball_speed': (7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (135, 50),
#   'blocker': (65, 240)},
#  {'frame': 23,
#   'status': 'GAME_ALIVE',
#   'ball': (56, 261),
#   'ball_speed': (7, -7),
#   'platform_1P': (80, 420),
#   'platform_2P': (135, 50),
#   'blocker': (60, 240)},
#  {'frame': 24,
#   'status': 'GAME_ALIVE',
#   'ball': (63, 260),
#   'ball_speed': (7, 7),
#   'platform_1P': (80, 420),
#   'platform_2P': (135, 50),
#   'blocker': (55, 240)},
#  {'frame': 25,
#   'status': 'GAME_ALIVE',
#   'ball': (70, 267),
#   'ball_speed': (7, 7),
#   'platform_1P': (85, 420),
#   'platform_2P': (135, 50),
#   'blocker': (50, 240)},
#  {'frame': 26,
#   'status': 'GAME_ALIVE',
#   'ball': (77, 274),
#   'ball_speed': (7, 7),
#   'platform_1P': (90, 420),
#   'platform_2P': (135, 50),
#   'blocker': (45, 240)},
#  {'frame': 27,
#   'status': 'GAME_ALIVE',
#   'ball': (84, 281),
#   'ball_speed': (7, 7),
#   'platform_1P': (95, 420),
#   'platform_2P': (135, 50),
#   'blocker': (40, 240)},
#  {'frame': 28,
#   'status': 'GAME_ALIVE',
#   'ball': (91, 288),
#   'ball_speed': (7, 7),
#   'platform_1P': (100, 420),
#   'platform_2P': (135, 50),
#   'blocker': (35, 240)},
#  {'frame': 29,
#   'status': 'GAME_ALIVE',
#   'ball': (98, 295),
#   'ball_speed': (7, 7),
#   'platform_1P': (105, 420),
#   'platform_2P': (135, 50),
#   'blocker': (30, 240)},
#  {'frame': 30,
#   'status': 'GAME_ALIVE',
#   'ball': (105, 302),
#   'ball_speed': (7, 7),
#   'platform_1P': (110, 420),
#   'platform_2P': (135, 50),
#   'blocker': (25, 240)},
#  {'frame': 31,
#   'status': 'GAME_ALIVE',
#   'ball': (112, 309),
#   'ball_speed': (7, 7),
#   'platform_1P': (115, 420),
#   'platform_2P': (135, 50),
#   'blocker': (20, 240)},
#  {'frame': 32,
#   'status': 'GAME_ALIVE',
#   'ball': (119, 316),
#   'ball_speed': (7, 7),
#   'platform_1P': (120, 420),
#   'platform_2P': (135, 50),
#   'blocker': (15, 240)},
#  {'frame': 33,
#   'status': 'GAME_ALIVE',
#   'ball': (126, 323),
#   'ball_speed': (7, 7),
#   'platform_1P': (125, 420),
#   'platform_2P': (135, 50),
#   'blocker': (10, 240)},
#  {'frame': 34,
#   'status': 'GAME_ALIVE',
#   'ball': (133, 330),
#   'ball_speed': (7, 7),
#   'platform_1P': (130, 420),
#   'platform_2P': (135, 50),
#   'blocker': (5, 240)},
#  {'frame': 35,
#   'status': 'GAME_ALIVE',
#   'ball': (140, 337),
#   'ball_speed': (7, 7),
#   'platform_1P': (135, 420),
#   'platform_2P': (135, 50),
#   'blocker': (0, 240)},
#  {'frame': 36,
#   'status': 'GAME_ALIVE',
#   'ball': (147, 344),
#   'ball_speed': (7, 7),
#   'platform_1P': (140, 420),
#   'platform_2P': (135, 50),
#   'blocker': (5, 240)},
#  {'frame': 37,
#   'status': 'GAME_ALIVE',
#   'ball': (154, 351),
#   'ball_speed': (7, 7),
#   'platform_1P': (145, 420),
#   'platform_2P': (135, 50),
#   'blocker': (10, 240)},
#  {'frame': 38,
#   'status': 'GAME_ALIVE',
#   'ball': (161, 358),
#   'ball_speed': (7, 7),
#   'platform_1P': (150, 420),
#   'platform_2P': (135, 50),
#   'blocker': (15, 240)},
#  {'frame': 39,
#   'status': 'GAME_ALIVE',
#   'ball': (168, 365),
#   'ball_speed': (7, 7),
#   'platform_1P': (150, 420),
#   'platform_2P': (135, 50),
#   'blocker': (20, 240)},
#  {'frame': 40,
#   'status': 'GAME_ALIVE',
#   'ball': (175, 372),
#   'ball_speed': (7, 7),
#   'platform_1P': (150, 420),
#   'platform_2P': (135, 50),
#   'blocker': (25, 240)},
#  {'frame': 41,
#   'status': 'GAME_ALIVE',
#   'ball': (182, 379),
#   'ball_speed': (7, 7),
#   'platform_1P': (150, 420),
#   'platform_2P': (135, 50),
#   'blocker': (30, 240)},
#  {'frame': 42,
#   'status': 'GAME_ALIVE',
#   'ball': (189, 386),
#   'ball_speed': (7, 7),
#   'platform_1P': (150, 420),
#   'platform_2P': (135, 50),
#   'blocker': (35, 240)},
#  {'frame': 43,
#   'status': 'GAME_ALIVE',
#   'ball': (195, 393),
#   'ball_speed': (-7, 7),
#   'platform_1P': (150, 420),
#   'platform_2P': (135, 50),
#   'blocker': (40, 240)},
#  {'frame': 44,
#   'status': 'GAME_ALIVE',
#   'ball': (188, 400),
#   'ball_speed': (-7, 7),
#   'platform_1P': (150, 420),
#   'platform_2P': (135, 50),
#   'blocker': (45, 240)},
#  {'frame': 45,
#   'status': 'GAME_ALIVE',
#   'ball': (181, 407),
#   'ball_speed': (-7, 7),
#   'platform_1P': (150, 420),
#   'platform_2P': (135, 50),
#   'blocker': (50, 240)},
#  {'frame': 46,
#   'status': 'GAME_ALIVE',
#   'ball': (174, 414),
#   'ball_speed': (-7, 7),
#   'platform_1P': (150, 420),
#   'platform_2P': (135, 50),
#   'blocker': (55, 240)},
#  {'frame': 47,
#   'status': 'GAME_ALIVE',
#   'ball': (167, 415),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (135, 50),
#   'blocker': (60, 240)},
#  {'frame': 48,
#   'status': 'GAME_ALIVE',
#   'ball': (160, 408),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (65, 240)},
#  {'frame': 49,
#   'status': 'GAME_ALIVE',
#   'ball': (153, 401),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (70, 240)},
#  {'frame': 50,
#   'status': 'GAME_ALIVE',
#   'ball': (146, 394),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (75, 240)},
#  {'frame': 51,
#   'status': 'GAME_ALIVE',
#   'ball': (139, 387),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (80, 240)},
#  {'frame': 52,
#   'status': 'GAME_ALIVE',
#   'ball': (132, 380),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (85, 240)},
#  {'frame': 53,
#   'status': 'GAME_ALIVE',
#   'ball': (125, 373),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (90, 240)},
#  {'frame': 54,
#   'status': 'GAME_ALIVE',
#   'ball': (118, 366),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (95, 240)},
#  {'frame': 55,
#   'status': 'GAME_ALIVE',
#   'ball': (111, 359),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (100, 240)},
#  {'frame': 56,
#   'status': 'GAME_ALIVE',
#   'ball': (104, 352),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (105, 240)},
#  {'frame': 57,
#   'status': 'GAME_ALIVE',
#   'ball': (97, 345),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (110, 240)},
#  {'frame': 58,
#   'status': 'GAME_ALIVE',
#   'ball': (90, 338),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (115, 240)},
#  {'frame': 59,
#   'status': 'GAME_ALIVE',
#   'ball': (83, 331),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (120, 240)},
#  {'frame': 60,
#   'status': 'GAME_ALIVE',
#   'ball': (76, 324),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (125, 240)},
#  {'frame': 61,
#   'status': 'GAME_ALIVE',
#   'ball': (69, 317),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (130, 240)},
#  {'frame': 62,
#   'status': 'GAME_ALIVE',
#   'ball': (62, 310),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (135, 240)},
#  {'frame': 63,
#   'status': 'GAME_ALIVE',
#   'ball': (55, 303),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (140, 240)},
#  {'frame': 64,
#   'status': 'GAME_ALIVE',
#   'ball': (48, 296),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (145, 240)},
#  {'frame': 65,
#   'status': 'GAME_ALIVE',
#   'ball': (41, 289),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (150, 240)},
#  {'frame': 66,
#   'status': 'GAME_ALIVE',
#   'ball': (34, 282),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (155, 240)},
#  {'frame': 67,
#   'status': 'GAME_ALIVE',
#   'ball': (27, 275),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (160, 240)},
#  {'frame': 68,
#   'status': 'GAME_ALIVE',
#   'ball': (20, 268),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (165, 240)},
#  {'frame': 69,
#   'status': 'GAME_ALIVE',
#   'ball': (13, 261),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (170, 240)},
#  {'frame': 70,
#   'status': 'GAME_ALIVE',
#   'ball': (6, 254),
#   'ball_speed': (-7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (165, 240)},
#  {'frame': 71,
#   'status': 'GAME_ALIVE',
#   'ball': (0, 247),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (160, 240)},
#  {'frame': 72,
#   'status': 'GAME_ALIVE',
#   'ball': (7, 240),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (155, 240)},
#  {'frame': 73,
#   'status': 'GAME_ALIVE',
#   'ball': (14, 233),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (150, 240)},
#  {'frame': 74,
#   'status': 'GAME_ALIVE',
#   'ball': (21, 226),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (145, 240)},
#  {'frame': 75,
#   'status': 'GAME_ALIVE',
#   'ball': (28, 219),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (140, 240)},
#  {'frame': 76,
#   'status': 'GAME_ALIVE',
#   'ball': (35, 212),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (135, 240)},
#  {'frame': 77,
#   'status': 'GAME_ALIVE',
#   'ball': (42, 205),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (130, 240)},
#  {'frame': 78,
#   'status': 'GAME_ALIVE',
#   'ball': (49, 198),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (125, 240)},
#  {'frame': 79,
#   'status': 'GAME_ALIVE',
#   'ball': (56, 191),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (120, 240)},
#  {'frame': 80,
#   'status': 'GAME_ALIVE',
#   'ball': (63, 184),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (115, 240)},
#  {'frame': 81,
#   'status': 'GAME_ALIVE',
#   'ball': (70, 177),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (110, 240)},
#  {'frame': 82,
#   'status': 'GAME_ALIVE',
#   'ball': (77, 170),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (105, 240)},
#  {'frame': 83,
#   'status': 'GAME_ALIVE',
#   'ball': (84, 163),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (100, 240)},
#  {'frame': 84,
#   'status': 'GAME_ALIVE',
#   'ball': (91, 156),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (95, 240)},
#  {'frame': 85,
#   'status': 'GAME_ALIVE',
#   'ball': (98, 149),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (90, 240)},
#  {'frame': 86,
#   'status': 'GAME_ALIVE',
#   'ball': (105, 142),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (85, 240)},
#  {'frame': 87,
#   'status': 'GAME_ALIVE',
#   'ball': (112, 135),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (80, 240)},
#  {'frame': 88,
#   'status': 'GAME_ALIVE',
#   'ball': (119, 128),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (75, 240)},
#  {'frame': 89,
#   'status': 'GAME_ALIVE',
#   'ball': (126, 121),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (70, 240)},
#  {'frame': 90,
#   'status': 'GAME_ALIVE',
#   'ball': (133, 114),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (65, 240)},
#  {'frame': 91,
#   'status': 'GAME_ALIVE',
#   'ball': (140, 107),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (60, 240)},
#  {'frame': 92,
#   'status': 'GAME_ALIVE',
#   'ball': (147, 100),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (55, 240)},
#  {'frame': 93,
#   'status': 'GAME_ALIVE',
#   'ball': (154, 93),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (50, 240)},
#  {'frame': 94,
#   'status': 'GAME_ALIVE',
#   'ball': (161, 86),
#   'ball_speed': (7, -7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (45, 240)},
#  {'frame': 95,
#   'status': 'GAME_ALIVE',
#   'ball': (168, 80),
#   'ball_speed': (7, 7),
#   'platform_1P': (150, 420),
#   'platform_2P': (140, 50),
#   'blocker': (40, 240)},
#  {'frame': 96,
#   'status': 'GAME_ALIVE',
#   'ball': (175, 87),
#   'ball_speed': (7, 7),
#   'platform_1P': (145, 420),
#   'platform_2P': (140, 50),
#   'blocker': (35, 240)},
#  {'frame': 97,
#   'status': 'GAME_ALIVE',
#   'ball': (182, 94),
#   'ball_speed': (7, 7),
#   'platform_1P': (140, 420),
#   'platform_2P': (140, 50),
#   'blocker': (30, 240)},
#  {'frame': 98,
#   'status': 'GAME_ALIVE',
#   'ball': (189, 101),
#   'ball_speed': (7, 7),
#   'platform_1P': (135, 420),
#   'platform_2P': (140, 50),
#   'blocker': (25, 240)},
#  {'frame': 99,
#   'status': 'GAME_ALIVE',
#   'ball': (195, 108),
#   'ball_speed': (-7, 7),
#   'platform_1P': (130, 420),
#   'platform_2P': (140, 50),
#   'blocker': (20, 240)},
#  {'frame': 100,
#   'status': 'GAME_ALIVE',
#   'ball': (188, 115),
#   'ball_speed': (-7, 7),
#   'platform_1P': (125, 420),
#   'platform_2P': (140, 50),
#   'blocker': (15, 240)},
#  {'frame': 101,
#   'status': 'GAME_ALIVE',
#   'ball': (180, 123),
#   'ball_speed': (-8, 8),
#   'platform_1P': (120, 420),
#   'platform_2P': (140, 50),
#   'blocker': (10, 240)},
#  {'frame': 102,
#   'status': 'GAME_ALIVE',
#   'ball': (172, 131),
#   'ball_speed': (-8, 8),
#   'platform_1P': (115, 420),
#   'platform_2P': (140, 50),
#   'blocker': (5, 240)},
#  {'frame': 103,
#   'status': 'GAME_ALIVE',
#   'ball': (164, 139),
#   'ball_speed': (-8, 8),
#   'platform_1P': (110, 420),
#   'platform_2P': (140, 50),
#   'blocker': (0, 240)},
#  {'frame': 104,
#   'status': 'GAME_ALIVE',
#   'ball': (156, 147),
#   'ball_speed': (-8, 8),
#   'platform_1P': (105, 420),
#   'platform_2P': (140, 50),
#   'blocker': (5, 240)},
#  {'frame': 105,
#   'status': 'GAME_ALIVE',
#   'ball': (148, 155),
#   'ball_speed': (-8, 8),
#   'platform_1P': (105, 420),
#   'platform_2P': (140, 50),
#   'blocker': (10, 240)},
#  {'frame': 106,
#   'status': 'GAME_ALIVE',
#   'ball': (140, 163),
#   'ball_speed': (-8, 8),
#   'platform_1P': (105, 420),
#   'platform_2P': (140, 50),
#   'blocker': (15, 240)},
#  {'frame': 107,
#   'status': 'GAME_ALIVE',
#   'ball': (132, 171),
#   'ball_speed': (-8, 8),
#   'platform_1P': (105, 420),
#   'platform_2P': (140, 50),
#   'blocker': (20, 240)},
#  {'frame': 108,
#   'status': 'GAME_ALIVE',
#   'ball': (124, 179),
#   'ball_speed': (-8, 8),
#   'platform_1P': (105, 420),
#   'platform_2P': (140, 50),
#   'blocker': (25, 240)},
#  {'frame': 109,
#   'status': 'GAME_ALIVE',
#   'ball': (116, 187),
#   'ball_speed': (-8, 8),
#   'platform_1P': (105, 420),
#   'platform_2P': (140, 50),
#   'blocker': (30, 240)},
#  {'frame': 110,
#   'status': 'GAME_ALIVE',
#   'ball': (108, 195),
#   'ball_speed': (-8, 8),
#   'platform_1P': (105, 420),
#   'platform_2P': (140, 50),
#   'blocker': (35, 240)},
#  {'frame': 111,
#   'status': 'GAME_ALIVE',
#   'ball': (100, 203),
#   'ball_speed': (-8, 8),
#   'platform_1P': (105, 420),
#   'platform_2P': (140, 50),
#   'blocker': (40, 240)},
#  {'frame': 112,
#   'status': 'GAME_ALIVE',
#   'ball': (92, 211),
#   'ball_speed': (-8, 8),
#   'platform_1P': (105, 420),
#   'platform_2P': (140, 50),
#   'blocker': (45, 240)},
#  {'frame': 113,
#   'status': 'GAME_ALIVE',
#   'ball': (84, 219),
#   'ball_speed': (-8, 8),
#   'platform_1P': (105, 420),
#   'platform_2P': (140, 50),
#   'blocker': (50, 240)},
#  {'frame': 114,
#   'status': 'GAME_ALIVE',
#   'ball': (76, 227),
#   'ball_speed': (-8, 8),
#   'platform_1P': (105, 420),
#   'platform_2P': (140, 50),
#   'blocker': (55, 240)},
#  {'frame': 115,
#   'status': 'GAME_ALIVE',
#   'ball': (68, 235),
#   'ball_speed': (-8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (140, 50),
#   'blocker': (60, 240)},
#  {'frame': 116,
#   'status': 'GAME_ALIVE',
#   'ball': (60, 227),
#   'ball_speed': (-8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (135, 50),
#   'blocker': (65, 240)},
#  {'frame': 117,
#   'status': 'GAME_ALIVE',
#   'ball': (52, 219),
#   'ball_speed': (-8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (130, 50),
#   'blocker': (70, 240)},
#  {'frame': 118,
#   'status': 'GAME_ALIVE',
#   'ball': (44, 211),
#   'ball_speed': (-8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (125, 50),
#   'blocker': (75, 240)},
#  {'frame': 119,
#   'status': 'GAME_ALIVE',
#   'ball': (36, 203),
#   'ball_speed': (-8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (120, 50),
#   'blocker': (80, 240)},
#  {'frame': 120,
#   'status': 'GAME_ALIVE',
#   'ball': (28, 195),
#   'ball_speed': (-8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (115, 50),
#   'blocker': (85, 240)},
#  {'frame': 121,
#   'status': 'GAME_ALIVE',
#   'ball': (20, 187),
#   'ball_speed': (-8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (110, 50),
#   'blocker': (90, 240)},
#  {'frame': 122,
#   'status': 'GAME_ALIVE',
#   'ball': (12, 179),
#   'ball_speed': (-8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (105, 50),
#   'blocker': (95, 240)},
#  {'frame': 123,
#   'status': 'GAME_ALIVE',
#   'ball': (4, 171),
#   'ball_speed': (-8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (100, 50),
#   'blocker': (100, 240)},
#  {'frame': 124,
#   'status': 'GAME_ALIVE',
#   'ball': (0, 163),
#   'ball_speed': (8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (95, 50),
#   'blocker': (105, 240)},
#  {'frame': 125,
#   'status': 'GAME_ALIVE',
#   'ball': (8, 155),
#   'ball_speed': (8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (90, 50),
#   'blocker': (110, 240)},
#  {'frame': 126,
#   'status': 'GAME_ALIVE',
#   'ball': (16, 147),
#   'ball_speed': (8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (85, 50),
#   'blocker': (115, 240)},
#  {'frame': 127,
#   'status': 'GAME_ALIVE',
#   'ball': (24, 139),
#   'ball_speed': (8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (80, 50),
#   'blocker': (120, 240)},
#  {'frame': 128,
#   'status': 'GAME_ALIVE',
#   'ball': (32, 131),
#   'ball_speed': (8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (75, 50),
#   'blocker': (125, 240)},
#  {'frame': 129,
#   'status': 'GAME_ALIVE',
#   'ball': (40, 123),
#   'ball_speed': (8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (70, 50),
#   'blocker': (130, 240)},
#  {'frame': 130,
#   'status': 'GAME_ALIVE',
#   'ball': (48, 115),
#   'ball_speed': (8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (70, 50),
#   'blocker': (135, 240)},
#  {'frame': 131,
#   'status': 'GAME_ALIVE',
#   'ball': (56, 107),
#   'ball_speed': (8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (70, 50),
#   'blocker': (140, 240)},
#  {'frame': 132,
#   'status': 'GAME_ALIVE',
#   'ball': (64, 99),
#   'ball_speed': (8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (70, 50),
#   'blocker': (145, 240)},
#  {'frame': 133,
#   'status': 'GAME_ALIVE',
#   'ball': (72, 91),
#   'ball_speed': (8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (70, 50),
#   'blocker': (150, 240)},
#  {'frame': 134,
#   'status': 'GAME_ALIVE',
#   'ball': (80, 83),
#   'ball_speed': (8, -8),
#   'platform_1P': (105, 420),
#   'platform_2P': (70, 50),
#   'blocker': (155, 240)},
#  {'frame': 135,
#   'status': 'GAME_ALIVE',
#   'ball': (88, 80),
#   'ball_speed': (8, 8),
#   'platform_1P': (105, 420),
#   'platform_2P': (70, 50),
#   'blocker': (160, 240)},
#  {'frame': 136,
#   'status': 'GAME_ALIVE',
#   'ball': (96, 88),
#   'ball_speed': (8, 8),
#   'platform_1P': (100, 420),
#   'platform_2P': (70, 50),
#   'blocker': (165, 240)},
#  {'frame': 137,
#   'status': 'GAME_ALIVE',
#   'ball': (104, 96),
#   'ball_speed': (8, 8),
#   'platform_1P': (95, 420),
#   'platform_2P': (70, 50),
#   'blocker': (170, 240)},
#  {'frame': 138,
#   'status': 'GAME_ALIVE',
#   'ball': (112, 104),
#   'ball_speed': (8, 8),
#   'platform_1P': (90, 420),
#   'platform_2P': (70, 50),
#   'blocker': (165, 240)},
#  {'frame': 139,
#   'status': 'GAME_ALIVE',
#   'ball': (120, 112),
#   'ball_speed': (8, 8),
#   'platform_1P': (85, 420),
#   'platform_2P': (70, 50),
#   'blocker': (160, 240)},
#  {'frame': 140,
#   'status': 'GAME_ALIVE',
#   'ball': (128, 120),
#   'ball_speed': (8, 8),
#   'platform_1P': (80, 420),
#   'platform_2P': (70, 50),
#   'blocker': (155, 240)},
#  {'frame': 141,
#   'status': 'GAME_ALIVE',
#   'ball': (136, 128),
#   'ball_speed': (8, 8),
#   'platform_1P': (75, 420),
#   'platform_2P': (70, 50),
#   'blocker': (150, 240)},
#  {'frame': 142,
#   'status': 'GAME_ALIVE',
#   'ball': (144, 136),
#   'ball_speed': (8, 8),
#   'platform_1P': (70, 420),
#   'platform_2P': (70, 50),
#   'blocker': (145, 240)},
#  {'frame': 143,
#   'status': 'GAME_ALIVE',
#   'ball': (152, 144),
#   'ball_speed': (8, 8),
#   'platform_1P': (65, 420),
#   'platform_2P': (70, 50),
#   'blocker': (140, 240)},
#  {'frame': 144,
#   'status': 'GAME_ALIVE',
#   'ball': (160, 152),
#   'ball_speed': (8, 8),
#   'platform_1P': (60, 420),
#   'platform_2P': (70, 50),
#   'blocker': (135, 240)},
#  {'frame': 145,
#   'status': 'GAME_ALIVE',
#   'ball': (168, 160),
#   'ball_speed': (8, 8),
#   'platform_1P': (55, 420),
#   'platform_2P': (70, 50),
#   'blocker': (130, 240)},
#  {'frame': 146,
#   'status': 'GAME_ALIVE',
#   'ball': (176, 168),
#   'ball_speed': (8, 8),
#   'platform_1P': (50, 420),
#   'platform_2P': (70, 50),
#   'blocker': (125, 240)},
#  {'frame': 147,
#   'status': 'GAME_ALIVE',
#   'ball': (184, 176),
#   'ball_speed': (8, 8),
#   'platform_1P': (45, 420),
#   'platform_2P': (70, 50),
#   'blocker': (120, 240)},
#  {'frame': 148,
#   'status': 'GAME_ALIVE',
#   'ball': (192, 184),
#   'ball_speed': (8, 8),
#   'platform_1P': (40, 420),
#   'platform_2P': (70, 50),
#   'blocker': (115, 240)},
#  {'frame': 149,
#   'status': 'GAME_ALIVE',
#   'ball': (195, 192),
#   'ball_speed': (-8, 8),
#   'platform_1P': (35, 420),
#   'platform_2P': (70, 50),
#   'blocker': (110, 240)},
#  {'frame': 150,
#   'status': 'GAME_ALIVE',
#   'ball': (187, 200),
#   'ball_speed': (-8, 8),
#   'platform_1P': (30, 420),
#   'platform_2P': (70, 50),
#   'blocker': (105, 240)},
#  {'frame': 151,
#   'status': 'GAME_ALIVE',
#   'ball': (179, 208),
#   'ball_speed': (-8, 8),
#   'platform_1P': (25, 420),
#   'platform_2P': (70, 50),
#   'blocker': (100, 240)},
#  {'frame': 152,
#   'status': 'GAME_ALIVE',
#   'ball': (171, 216),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (95, 240)},
#  {'frame': 153,
#   'status': 'GAME_ALIVE',
#   'ball': (163, 224),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (90, 240)},
#  {'frame': 154,
#   'status': 'GAME_ALIVE',
#   'ball': (155, 232),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (85, 240)},
#  {'frame': 155,
#   'status': 'GAME_ALIVE',
#   'ball': (147, 240),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (80, 240)},
#  {'frame': 156,
#   'status': 'GAME_ALIVE',
#   'ball': (139, 248),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (75, 240)},
#  {'frame': 157,
#   'status': 'GAME_ALIVE',
#   'ball': (131, 256),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (70, 240)},
#  {'frame': 158,
#   'status': 'GAME_ALIVE',
#   'ball': (123, 264),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (65, 240)},
#  {'frame': 159,
#   'status': 'GAME_ALIVE',
#   'ball': (115, 272),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (60, 240)},
#  {'frame': 160,
#   'status': 'GAME_ALIVE',
#   'ball': (107, 280),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (55, 240)},
#  {'frame': 161,
#   'status': 'GAME_ALIVE',
#   'ball': (99, 288),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (50, 240)},
#  {'frame': 162,
#   'status': 'GAME_ALIVE',
#   'ball': (91, 296),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (45, 240)},
#  {'frame': 163,
#   'status': 'GAME_ALIVE',
#   'ball': (83, 304),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (40, 240)},
#  {'frame': 164,
#   'status': 'GAME_ALIVE',
#   'ball': (75, 312),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (35, 240)},
#  {'frame': 165,
#   'status': 'GAME_ALIVE',
#   'ball': (67, 320),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (30, 240)},
#  {'frame': 166,
#   'status': 'GAME_ALIVE',
#   'ball': (59, 328),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (25, 240)},
#  {'frame': 167,
#   'status': 'GAME_ALIVE',
#   'ball': (51, 336),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (20, 240)},
#  {'frame': 168,
#   'status': 'GAME_ALIVE',
#   'ball': (43, 344),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (15, 240)},
#  {'frame': 169,
#   'status': 'GAME_ALIVE',
#   'ball': (35, 352),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (10, 240)},
#  {'frame': 170,
#   'status': 'GAME_ALIVE',
#   'ball': (27, 360),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (5, 240)},
#  {'frame': 171,
#   'status': 'GAME_ALIVE',
#   'ball': (19, 368),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (0, 240)},
#  {'frame': 172,
#   'status': 'GAME_ALIVE',
#   'ball': (11, 376),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (5, 240)},
#  {'frame': 173,
#   'status': 'GAME_ALIVE',
#   'ball': (3, 384),
#   'ball_speed': (-8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (10, 240)},
#  {'frame': 174,
#   'status': 'GAME_ALIVE',
#   'ball': (0, 392),
#   'ball_speed': (8, 8),
#   'platform_1P': (20, 420),
#   'platform_2P': (70, 50),
#   'blocker': (15, 240)},
#  {'frame': 175,
#   'status': 'GAME_ALIVE',
#   'ball': (8, 400),
#   'ball_speed': (8, 8),
#   'platform_1P': (15, 420),
#   'platform_2P': (70, 50),
#   'blocker': (20, 240)},
#  {'frame': 176,
#   'status': 'GAME_ALIVE',
#   'ball': (16, 408),
#   'ball_speed': (8, 8),
#   'platform_1P': (15, 420),
#   'platform_2P': (70, 50),
#   'blocker': (25, 240)},
#  {'frame': 177,
#   'status': 'GAME_ALIVE',
#   'ball': (24, 415),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (70, 50),
#   'blocker': (30, 240)},
#  {'frame': 178,
#   'status': 'GAME_ALIVE',
#   'ball': (32, 407),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (65, 50),
#   'blocker': (35, 240)},
#  {'frame': 179,
#   'status': 'GAME_ALIVE',
#   'ball': (40, 399),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (60, 50),
#   'blocker': (40, 240)},
#  {'frame': 180,
#   'status': 'GAME_ALIVE',
#   'ball': (48, 391),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (55, 50),
#   'blocker': (45, 240)},
#  {'frame': 181,
#   'status': 'GAME_ALIVE',
#   'ball': (56, 383),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (50, 50),
#   'blocker': (50, 240)},
#  {'frame': 182,
#   'status': 'GAME_ALIVE',
#   'ball': (64, 375),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (45, 50),
#   'blocker': (55, 240)},
#  {'frame': 183,
#   'status': 'GAME_ALIVE',
#   'ball': (72, 367),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (40, 50),
#   'blocker': (60, 240)},
#  {'frame': 184,
#   'status': 'GAME_ALIVE',
#   'ball': (80, 359),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (35, 50),
#   'blocker': (65, 240)},
#  {'frame': 185,
#   'status': 'GAME_ALIVE',
#   'ball': (88, 351),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (30, 50),
#   'blocker': (70, 240)},
#  {'frame': 186,
#   'status': 'GAME_ALIVE',
#   'ball': (96, 343),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (30, 50),
#   'blocker': (75, 240)},
#  {'frame': 187,
#   'status': 'GAME_ALIVE',
#   'ball': (104, 335),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (30, 50),
#   'blocker': (80, 240)},
#  {'frame': 188,
#   'status': 'GAME_ALIVE',
#   'ball': (112, 327),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (30, 50),
#   'blocker': (85, 240)},
#  {'frame': 189,
#   'status': 'GAME_ALIVE',
#   'ball': (120, 319),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (30, 50),
#   'blocker': (90, 240)},
#  {'frame': 190,
#   'status': 'GAME_ALIVE',
#   'ball': (128, 311),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (30, 50),
#   'blocker': (95, 240)},
#  {'frame': 191,
#   'status': 'GAME_ALIVE',
#   'ball': (136, 303),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (30, 50),
#   'blocker': (100, 240)},
#  {'frame': 192,
#   'status': 'GAME_ALIVE',
#   'ball': (144, 295),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (30, 50),
#   'blocker': (105, 240)},
#  {'frame': 193,
#   'status': 'GAME_ALIVE',
#   'ball': (152, 287),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (30, 50),
#   'blocker': (110, 240)},
#  {'frame': 194,
#   'status': 'GAME_ALIVE',
#   'ball': (160, 279),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (30, 50),
#   'blocker': (115, 240)},
#  {'frame': 195,
#   'status': 'GAME_ALIVE',
#   'ball': (168, 271),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (30, 50),
#   'blocker': (120, 240)},
#  {'frame': 196,
#   'status': 'GAME_ALIVE',
#   'ball': (176, 263),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (30, 50),
#   'blocker': (125, 240)},
#  {'frame': 197,
#   'status': 'GAME_ALIVE',
#   'ball': (184, 255),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (30, 50),
#   'blocker': (130, 240)},
#  {'frame': 198,
#   'status': 'GAME_ALIVE',
#   'ball': (192, 247),
#   'ball_speed': (8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (30, 50),
#   'blocker': (135, 240)},
#  {'frame': 199,
#   'status': 'GAME_ALIVE',
#   'ball': (195, 239),
#   'ball_speed': (-8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (30, 50),
#   'blocker': (140, 240)},
#  {'frame': 200,
#   'status': 'GAME_ALIVE',
#   'ball': (187, 231),
#   'ball_speed': (-8, -8),
#   'platform_1P': (15, 420),
#   'platform_2P': (25, 50),
#   'blocker': (145, 240)},
#  {'frame': 201,
#   'status': 'GAME_ALIVE',
#   'ball': (178, 222),
#   'ball_speed': (-9, -9),
#   'platform_1P': (15, 420),
#   'platform_2P': (25, 50),
#   'blocker': (150, 240)},
#  {'frame': 202,
#   'status': 'GAME_ALIVE',
#   'ball': (169, 213),
#   'ball_speed': (-9, -9),
#   'platform_1P': (15, 420),
#   'platform_2P': (25, 50),
#   'blocker': (155, 240)},
#  {'frame': 203,
#   'status': 'GAME_ALIVE',
#   'ball': (160, 204),
#   'ball_speed': (-9, -9),
#   'platform_1P': (15, 420),
#   'platform_2P': (25, 50),
#   'blocker': (160, 240)},
#  {'frame': 204,
#   'status': 'GAME_ALIVE',
#   'ball': (151, 195),
#   'ball_speed': (-9, -9),
#   'platform_1P': (15, 420),
#   'platform_2P': (25, 50),
#   'blocker': (165, 240)},
#  {'frame': 205,
#   'status': 'GAME_ALIVE',
#   'ball': (142, 186),
#   'ball_speed': (-9, -9),
#   'platform_1P': (15, 420),
#   'platform_2P': (25, 50),
#   'blocker': (170, 240)},
#  {'frame': 206,
#   'status': 'GAME_ALIVE',
#   'ball': (133, 177),
#   'ball_speed': (-9, -9),
#   'platform_1P': (15, 420),
#   'platform_2P': (25, 50),
#   'blocker': (165, 240)},
#  {'frame': 207,
#   'status': 'GAME_ALIVE',
#   'ball': (124, 168),
#   'ball_speed': (-9, -9),
#   'platform_1P': (15, 420),
#   'platform_2P': (25, 50),
#   'blocker': (160, 240)},
#  {'frame': 208,
#   'status': 'GAME_ALIVE',
#   'ball': (115, 159),
#   'ball_speed': (-9, -9),
#   'platform_1P': (15, 420),
#   'platform_2P': (25, 50),
#   'blocker': (155, 240)},
#  {'frame': 209,
#   'status': 'GAME_ALIVE',
#   'ball': (106, 150),
#   'ball_speed': (-9, -9),
#   'platform_1P': (15, 420),
#   'platform_2P': (25, 50),
#   'blocker': (150, 240)},
#  {'frame': 210,
#   'status': 'GAME_ALIVE',
#   'ball': (97, 141),
#   'ball_speed': (-9, -9),
#   'platform_1P': (15, 420),
#   'platform_2P': (25, 50),
#   'blocker': (145, 240)},
#  {'frame': 211,
#   'status': 'GAME_ALIVE',
#   'ball': (88, 132),
#   'ball_speed': (-9, -9),
#   'platform_1P': (15, 420),
#   'platform_2P': (25, 50),
#   'blocker': (140, 240)},
#  {'frame': 212,
#   'status': 'GAME_ALIVE',
#   'ball': (79, 123),
#   'ball_speed': (-9, -9),
#   'platform_1P': (15, 420),
#   'platform_2P': (25, 50),
#   'blocker': (135, 240)},
#  {'frame': 213,
#   'status': 'GAME_ALIVE',
#   'ball': (70, 114),
#   'ball_speed': (-9, -9),
#   'platform_1P': (15, 420),
#   'platform_2P': (25, 50),
#   'blocker': (130, 240)},
#  {'frame': 214,
#   'status': 'GAME_ALIVE',
#   'ball': (61, 105),
#   'ball_speed': (-9, -9),
#   'platform_1P': (15, 420),
#   'platform_2P': (25, 50),
#   'blocker': (125, 240)},
#  {'frame': 215,
#   'status': 'GAME_ALIVE',
#   'ball': (52, 96),
#   'ball_speed': (-9, -9),
#   'platform_1P': (15, 420),
#   'platform_2P': (25, 50),
#   'blocker': (120, 240)},
#  {'frame': 216,
#   'status': 'GAME_ALIVE',
#   'ball': (43, 87),
#   'ball_speed': (-9, -9),
#   'platform_1P': (15, 420),
#   'platform_2P': (25, 50),
#   'blocker': (115, 240)},
#  {'frame': 217,
#   'status': 'GAME_ALIVE',
#   'ball': (34, 80),
#   'ball_speed': (-9, 9),
#   'platform_1P': (15, 420),
#   'platform_2P': (25, 50),
#   'blocker': (110, 240)},
#  {'frame': 218,
#   'status': 'GAME_ALIVE',
#   'ball': (25, 89),
#   'ball_speed': (-9, 9),
#   'platform_1P': (20, 420),
#   'platform_2P': (25, 50),
#   'blocker': (105, 240)},
#  {'frame': 219,
#   'status': 'GAME_ALIVE',
#   'ball': (16, 98),
#   'ball_speed': (-9, 9),
#   'platform_1P': (25, 420),
#   'platform_2P': (25, 50),
#   'blocker': (100, 240)},
#  {'frame': 220,
#   'status': 'GAME_ALIVE',
#   'ball': (7, 107),
#   'ball_speed': (-9, 9),
#   'platform_1P': (30, 420),
#   'platform_2P': (25, 50),
#   'blocker': (95, 240)},
#  {'frame': 221,
#   'status': 'GAME_ALIVE',
#   'ball': (0, 116),
#   'ball_speed': (9, 9),
#   'platform_1P': (35, 420),
#   'platform_2P': (25, 50),
#   'blocker': (90, 240)},
#  {'frame': 222,
#   'status': 'GAME_ALIVE',
#   'ball': (9, 125),
#   'ball_speed': (9, 9),
#   'platform_1P': (40, 420),
#   'platform_2P': (25, 50),
#   'blocker': (85, 240)},
#  {'frame': 223,
#   'status': 'GAME_ALIVE',
#   'ball': (18, 134),
#   'ball_speed': (9, 9),
#   'platform_1P': (45, 420),
#   'platform_2P': (25, 50),
#   'blocker': (80, 240)},
#  {'frame': 224,
#   'status': 'GAME_ALIVE',
#   'ball': (27, 143),
#   'ball_speed': (9, 9),
#   'platform_1P': (50, 420),
#   'platform_2P': (25, 50),
#   'blocker': (75, 240)},
#  {'frame': 225,
#   'status': 'GAME_ALIVE',
#   'ball': (36, 152),
#   'ball_speed': (9, 9),
#   'platform_1P': (55, 420),
#   'platform_2P': (25, 50),
#   'blocker': (70, 240)},
#  {'frame': 226,
#   'status': 'GAME_ALIVE',
#   'ball': (45, 161),
#   'ball_speed': (9, 9),
#   'platform_1P': (60, 420),
#   'platform_2P': (25, 50),
#   'blocker': (65, 240)},
#  {'frame': 227,
#   'status': 'GAME_ALIVE',
#   'ball': (54, 170),
#   'ball_speed': (9, 9),
#   'platform_1P': (65, 420),
#   'platform_2P': (25, 50),
#   'blocker': (60, 240)},
#  {'frame': 228,
#   'status': 'GAME_ALIVE',
#   'ball': (63, 179),
#   'ball_speed': (9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (55, 240)},
#  {'frame': 229,
#   'status': 'GAME_ALIVE',
#   'ball': (72, 188),
#   'ball_speed': (9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (50, 240)},
#  {'frame': 230,
#   'status': 'GAME_ALIVE',
#   'ball': (81, 197),
#   'ball_speed': (9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (45, 240)},
#  {'frame': 231,
#   'status': 'GAME_ALIVE',
#   'ball': (90, 206),
#   'ball_speed': (9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (40, 240)},
#  {'frame': 232,
#   'status': 'GAME_ALIVE',
#   'ball': (99, 215),
#   'ball_speed': (9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (35, 240)},
#  {'frame': 233,
#   'status': 'GAME_ALIVE',
#   'ball': (108, 224),
#   'ball_speed': (9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (30, 240)},
#  {'frame': 234,
#   'status': 'GAME_ALIVE',
#   'ball': (117, 233),
#   'ball_speed': (9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (25, 240)},
#  {'frame': 235,
#   'status': 'GAME_ALIVE',
#   'ball': (126, 242),
#   'ball_speed': (9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (20, 240)},
#  {'frame': 236,
#   'status': 'GAME_ALIVE',
#   'ball': (135, 251),
#   'ball_speed': (9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (15, 240)},
#  {'frame': 237,
#   'status': 'GAME_ALIVE',
#   'ball': (144, 260),
#   'ball_speed': (9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (10, 240)},
#  {'frame': 238,
#   'status': 'GAME_ALIVE',
#   'ball': (153, 269),
#   'ball_speed': (9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (5, 240)},
#  {'frame': 239,
#   'status': 'GAME_ALIVE',
#   'ball': (162, 278),
#   'ball_speed': (9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (0, 240)},
#  {'frame': 240,
#   'status': 'GAME_ALIVE',
#   'ball': (171, 287),
#   'ball_speed': (9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (5, 240)},
#  {'frame': 241,
#   'status': 'GAME_ALIVE',
#   'ball': (180, 296),
#   'ball_speed': (9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (10, 240)},
#  {'frame': 242,
#   'status': 'GAME_ALIVE',
#   'ball': (189, 305),
#   'ball_speed': (9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (15, 240)},
#  {'frame': 243,
#   'status': 'GAME_ALIVE',
#   'ball': (195, 314),
#   'ball_speed': (-9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (20, 240)},
#  {'frame': 244,
#   'status': 'GAME_ALIVE',
#   'ball': (186, 323),
#   'ball_speed': (-9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (25, 240)},
#  {'frame': 245,
#   'status': 'GAME_ALIVE',
#   'ball': (177, 332),
#   'ball_speed': (-9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (30, 240)},
#  {'frame': 246,
#   'status': 'GAME_ALIVE',
#   'ball': (168, 341),
#   'ball_speed': (-9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (35, 240)},
#  {'frame': 247,
#   'status': 'GAME_ALIVE',
#   'ball': (159, 350),
#   'ball_speed': (-9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (40, 240)},
#  {'frame': 248,
#   'status': 'GAME_ALIVE',
#   'ball': (150, 359),
#   'ball_speed': (-9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (45, 240)},
#  {'frame': 249,
#   'status': 'GAME_ALIVE',
#   'ball': (141, 368),
#   'ball_speed': (-9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (50, 240)},
#  {'frame': 250,
#   'status': 'GAME_ALIVE',
#   'ball': (132, 377),
#   'ball_speed': (-9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (55, 240)},
#  {'frame': 251,
#   'status': 'GAME_ALIVE',
#   'ball': (123, 386),
#   'ball_speed': (-9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (60, 240)},
#  {'frame': 252,
#   'status': 'GAME_ALIVE',
#   'ball': (114, 395),
#   'ball_speed': (-9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (65, 240)},
#  {'frame': 253,
#   'status': 'GAME_ALIVE',
#   'ball': (105, 404),
#   'ball_speed': (-9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (70, 240)},
#  {'frame': 254,
#   'status': 'GAME_ALIVE',
#   'ball': (96, 413),
#   'ball_speed': (-9, 9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (75, 240)},
#  {'frame': 255,
#   'status': 'GAME_ALIVE',
#   'ball': (87, 415),
#   'ball_speed': (-9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (25, 50),
#   'blocker': (80, 240)},
#  {'frame': 256,
#   'status': 'GAME_ALIVE',
#   'ball': (78, 406),
#   'ball_speed': (-9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (30, 50),
#   'blocker': (85, 240)},
#  {'frame': 257,
#   'status': 'GAME_ALIVE',
#   'ball': (69, 397),
#   'ball_speed': (-9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (35, 50),
#   'blocker': (90, 240)},
#  {'frame': 258,
#   'status': 'GAME_ALIVE',
#   'ball': (60, 388),
#   'ball_speed': (-9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (40, 50),
#   'blocker': (95, 240)},
#  {'frame': 259,
#   'status': 'GAME_ALIVE',
#   'ball': (51, 379),
#   'ball_speed': (-9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (45, 50),
#   'blocker': (100, 240)},
#  {'frame': 260,
#   'status': 'GAME_ALIVE',
#   'ball': (42, 370),
#   'ball_speed': (-9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (50, 50),
#   'blocker': (105, 240)},
#  {'frame': 261,
#   'status': 'GAME_ALIVE',
#   'ball': (33, 361),
#   'ball_speed': (-9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (55, 50),
#   'blocker': (110, 240)},
#  {'frame': 262,
#   'status': 'GAME_ALIVE',
#   'ball': (24, 352),
#   'ball_speed': (-9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (60, 50),
#   'blocker': (115, 240)},
#  {'frame': 263,
#   'status': 'GAME_ALIVE',
#   'ball': (15, 343),
#   'ball_speed': (-9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (65, 50),
#   'blocker': (120, 240)},
#  {'frame': 264,
#   'status': 'GAME_ALIVE',
#   'ball': (6, 334),
#   'ball_speed': (-9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (70, 50),
#   'blocker': (125, 240)},
#  {'frame': 265,
#   'status': 'GAME_ALIVE',
#   'ball': (0, 325),
#   'ball_speed': (9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (75, 50),
#   'blocker': (130, 240)},
#  {'frame': 266,
#   'status': 'GAME_ALIVE',
#   'ball': (9, 316),
#   'ball_speed': (9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (80, 50),
#   'blocker': (135, 240)},
#  {'frame': 267,
#   'status': 'GAME_ALIVE',
#   'ball': (18, 307),
#   'ball_speed': (9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (85, 50),
#   'blocker': (140, 240)},
#  {'frame': 268,
#   'status': 'GAME_ALIVE',
#   'ball': (27, 298),
#   'ball_speed': (9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (90, 50),
#   'blocker': (145, 240)},
#  {'frame': 269,
#   'status': 'GAME_ALIVE',
#   'ball': (36, 289),
#   'ball_speed': (9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (95, 50),
#   'blocker': (150, 240)},
#  {'frame': 270,
#   'status': 'GAME_ALIVE',
#   'ball': (45, 280),
#   'ball_speed': (9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (100, 50),
#   'blocker': (155, 240)},
#  {'frame': 271,
#   'status': 'GAME_ALIVE',
#   'ball': (54, 271),
#   'ball_speed': (9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (105, 50),
#   'blocker': (160, 240)},
#  {'frame': 272,
#   'status': 'GAME_ALIVE',
#   'ball': (63, 262),
#   'ball_speed': (9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (110, 50),
#   'blocker': (165, 240)},
#  {'frame': 273,
#   'status': 'GAME_ALIVE',
#   'ball': (72, 253),
#   'ball_speed': (9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (115, 50),
#   'blocker': (170, 240)},
#  {'frame': 274,
#   'status': 'GAME_ALIVE',
#   'ball': (81, 244),
#   'ball_speed': (9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (120, 50),
#   'blocker': (165, 240)},
#  {'frame': 275,
#   'status': 'GAME_ALIVE',
#   'ball': (90, 235),
#   'ball_speed': (9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (125, 50),
#   'blocker': (160, 240)},
#  {'frame': 276,
#   'status': 'GAME_ALIVE',
#   'ball': (99, 226),
#   'ball_speed': (9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (125, 50),
#   'blocker': (155, 240)},
#  {'frame': 277,
#   'status': 'GAME_ALIVE',
#   'ball': (108, 217),
#   'ball_speed': (9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (125, 50),
#   'blocker': (150, 240)},
#  {'frame': 278,
#   'status': 'GAME_ALIVE',
#   'ball': (117, 208),
#   'ball_speed': (9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (125, 50),
#   'blocker': (145, 240)},
#  {'frame': 279,
#   'status': 'GAME_ALIVE',
#   'ball': (126, 199),
#   'ball_speed': (9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (125, 50),
#   'blocker': (140, 240)},
#  {'frame': 280,
#   'status': 'GAME_ALIVE',
#   'ball': (135, 190),
#   'ball_speed': (9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (125, 50),
#   'blocker': (135, 240)},
#  {'frame': 281,
#   'status': 'GAME_ALIVE',
#   'ball': (144, 181),
#   'ball_speed': (9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (125, 50),
#   'blocker': (130, 240)},
#  {'frame': 282,
#   'status': 'GAME_ALIVE',
#   'ball': (153, 172),
#   'ball_speed': (9, -9),
#   'platform_1P': (70, 420),
#   'platform_2P': (125, 50),
#   'blocker': (125, 240)},
#  {'frame': 283,
#   'status': 'GAME_ALIVE',
#   'ball': (162, 163),
#   'ball_speed': (9, -9),
# ...
#   'blocker': (45, 240)},
#  {'frame': 453,
#   'status': 'GAME_ALIVE',
#   'ball': (85, 399),
#   'ball_speed': (-11, 11),
#   'platform_1P': (45, 420),
#   'platform_2P': (5, 50),
#   'blocker': (50, 240)},
#  {'frame': 454,
#   'status': 'GAME_ALIVE',
#   'ball': (74, 410),
#   'ball_speed': (-11, 11),
#   'platform_1P': (45, 420),
#   'platform_2P': (5, 50),
#   'blocker': (55, 240)},
#  {'frame': 455,
#   'status': 'GAME_ALIVE',
#   'ball': (63, 415),
#   'ball_speed': (-11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (5, 50),
#   'blocker': (60, 240)},
#  {'frame': 456,
#   'status': 'GAME_ALIVE',
#   'ball': (52, 404),
#   'ball_speed': (-11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (10, 50),
#   'blocker': (65, 240)},
#  {'frame': 457,
#   'status': 'GAME_ALIVE',
#   'ball': (41, 393),
#   'ball_speed': (-11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (15, 50),
#   'blocker': (70, 240)},
#  {'frame': 458,
#   'status': 'GAME_ALIVE',
#   'ball': (30, 382),
#   'ball_speed': (-11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (20, 50),
#   'blocker': (75, 240)},
#  {'frame': 459,
#   'status': 'GAME_ALIVE',
#   'ball': (19, 371),
#   'ball_speed': (-11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (25, 50),
#   'blocker': (80, 240)},
#  {'frame': 460,
#   'status': 'GAME_ALIVE',
#   'ball': (8, 360),
#   'ball_speed': (-11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (30, 50),
#   'blocker': (85, 240)},
#  {'frame': 461,
#   'status': 'GAME_ALIVE',
#   'ball': (0, 349),
#   'ball_speed': (11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (35, 50),
#   'blocker': (90, 240)},
#  {'frame': 462,
#   'status': 'GAME_ALIVE',
#   'ball': (11, 338),
#   'ball_speed': (11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (40, 50),
#   'blocker': (95, 240)},
#  {'frame': 463,
#   'status': 'GAME_ALIVE',
#   'ball': (22, 327),
#   'ball_speed': (11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (45, 50),
#   'blocker': (100, 240)},
#  {'frame': 464,
#   'status': 'GAME_ALIVE',
#   'ball': (33, 316),
#   'ball_speed': (11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (50, 50),
#   'blocker': (105, 240)},
#  {'frame': 465,
#   'status': 'GAME_ALIVE',
#   'ball': (44, 305),
#   'ball_speed': (11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (55, 50),
#   'blocker': (110, 240)},
#  {'frame': 466,
#   'status': 'GAME_ALIVE',
#   'ball': (55, 294),
#   'ball_speed': (11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (60, 50),
#   'blocker': (115, 240)},
#  {'frame': 467,
#   'status': 'GAME_ALIVE',
#   'ball': (66, 283),
#   'ball_speed': (11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (65, 50),
#   'blocker': (120, 240)},
#  {'frame': 468,
#   'status': 'GAME_ALIVE',
#   'ball': (77, 272),
#   'ball_speed': (11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (70, 50),
#   'blocker': (125, 240)},
#  {'frame': 469,
#   'status': 'GAME_ALIVE',
#   'ball': (88, 261),
#   'ball_speed': (11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (75, 50),
#   'blocker': (130, 240)},
#  {'frame': 470,
#   'status': 'GAME_ALIVE',
#   'ball': (99, 250),
#   'ball_speed': (11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (80, 50),
#   'blocker': (135, 240)},
#  {'frame': 471,
#   'status': 'GAME_ALIVE',
#   'ball': (110, 239),
#   'ball_speed': (11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (85, 50),
#   'blocker': (140, 240)},
#  {'frame': 472,
#   'status': 'GAME_ALIVE',
#   'ball': (121, 228),
#   'ball_speed': (11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (90, 50),
#   'blocker': (145, 240)},
#  {'frame': 473,
#   'status': 'GAME_ALIVE',
#   'ball': (132, 217),
#   'ball_speed': (11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (95, 50),
#   'blocker': (150, 240)},
#  {'frame': 474,
#   'status': 'GAME_ALIVE',
#   'ball': (143, 206),
#   'ball_speed': (11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (100, 50),
#   'blocker': (155, 240)},
#  {'frame': 475,
#   'status': 'GAME_ALIVE',
#   'ball': (154, 195),
#   'ball_speed': (11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (105, 50),
#   'blocker': (160, 240)},
#  {'frame': 476,
#   'status': 'GAME_ALIVE',
#   'ball': (165, 184),
#   'ball_speed': (11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (105, 50),
#   'blocker': (165, 240)},
#  {'frame': 477,
#   'status': 'GAME_ALIVE',
#   'ball': (176, 173),
#   'ball_speed': (11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (105, 50),
#   'blocker': (170, 240)},
#  {'frame': 478,
#   'status': 'GAME_ALIVE',
#   'ball': (187, 162),
#   'ball_speed': (11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (105, 50),
#   'blocker': (165, 240)},
#  {'frame': 479,
#   'status': 'GAME_ALIVE',
#   'ball': (195, 151),
#   'ball_speed': (-11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (105, 50),
#   'blocker': (160, 240)},
#  {'frame': 480,
#   'status': 'GAME_ALIVE',
#   'ball': (184, 140),
#   'ball_speed': (-11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (105, 50),
#   'blocker': (155, 240)},
#  {'frame': 481,
#   'status': 'GAME_ALIVE',
#   'ball': (173, 129),
#   'ball_speed': (-11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (105, 50),
#   'blocker': (150, 240)},
#  {'frame': 482,
#   'status': 'GAME_ALIVE',
#   'ball': (162, 118),
#   'ball_speed': (-11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (105, 50),
#   'blocker': (145, 240)},
#  {'frame': 483,
#   'status': 'GAME_ALIVE',
#   'ball': (151, 107),
#   'ball_speed': (-11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (105, 50),
#   'blocker': (140, 240)},
#  {'frame': 484,
#   'status': 'GAME_ALIVE',
#   'ball': (140, 96),
#   'ball_speed': (-11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (105, 50),
#   'blocker': (135, 240)},
#  {'frame': 485,
#   'status': 'GAME_ALIVE',
#   'ball': (129, 85),
#   'ball_speed': (-11, -11),
#   'platform_1P': (45, 420),
#   'platform_2P': (105, 50),
#   'blocker': (130, 240)},
#  {'frame': 486,
#   'status': 'GAME_ALIVE',
#   'ball': (118, 80),
#   'ball_speed': (-11, 11),
#   'platform_1P': (45, 420),
#   'platform_2P': (105, 50),
#   'blocker': (125, 240)},
#  {'frame': 487,
#   'status': 'GAME_ALIVE',
#   'ball': (107, 91),
#   'ball_speed': (-11, 11),
#   'platform_1P': (50, 420),
#   'platform_2P': (105, 50),
#   'blocker': (120, 240)},
#  {'frame': 488,
#   'status': 'GAME_ALIVE',
#   'ball': (96, 102),
#   'ball_speed': (-11, 11),
#   'platform_1P': (55, 420),
#   'platform_2P': (105, 50),
#   'blocker': (115, 240)},
#  {'frame': 489,
#   'status': 'GAME_ALIVE',
#   'ball': (85, 113),
#   'ball_speed': (-11, 11),
#   'platform_1P': (60, 420),
#   'platform_2P': (105, 50),
#   'blocker': (110, 240)},
#  {'frame': 490,
#   'status': 'GAME_ALIVE',
#   'ball': (74, 124),
#   'ball_speed': (-11, 11),
#   'platform_1P': (65, 420),
#   'platform_2P': (105, 50),
#   'blocker': (105, 240)},
#  {'frame': 491,
#   'status': 'GAME_ALIVE',
#   'ball': (63, 135),
#   'ball_speed': (-11, 11),
#   'platform_1P': (70, 420),
#   'platform_2P': (105, 50),
#   'blocker': (100, 240)},
#  {'frame': 492,
#   'status': 'GAME_ALIVE',
#   'ball': (52, 146),
#   'ball_speed': (-11, 11),
#   'platform_1P': (75, 420),
#   'platform_2P': (105, 50),
#   'blocker': (95, 240)},
#  {'frame': 493,
#   'status': 'GAME_ALIVE',
#   'ball': (41, 157),
#   'ball_speed': (-11, 11),
#   'platform_1P': (80, 420),
#   'platform_2P': (105, 50),
#   'blocker': (90, 240)},
#  {'frame': 494,
#   'status': 'GAME_ALIVE',
#   'ball': (30, 168),
#   'ball_speed': (-11, 11),
#   'platform_1P': (85, 420),
#   'platform_2P': (105, 50),
#   'blocker': (85, 240)},
#  {'frame': 495,
#   'status': 'GAME_ALIVE',
#   'ball': (19, 179),
#   'ball_speed': (-11, 11),
#   'platform_1P': (90, 420),
#   'platform_2P': (105, 50),
#   'blocker': (80, 240)},
#  {'frame': 496,
#   'status': 'GAME_ALIVE',
#   'ball': (8, 190),
#   'ball_speed': (-11, 11),
#   'platform_1P': (95, 420),
#   'platform_2P': (105, 50),
#   'blocker': (75, 240)},
#  {'frame': 497,
#   'status': 'GAME_ALIVE',
#   'ball': (0, 201),
#   'ball_speed': (11, 11),
#   'platform_1P': (100, 420),
#   'platform_2P': (105, 50),
#   'blocker': (70, 240)},
#  {'frame': 498,
#   'status': 'GAME_ALIVE',
#   'ball': (11, 212),
#   'ball_speed': (11, 11),
#   'platform_1P': (105, 420),
#   'platform_2P': (105, 50),
#   'blocker': (65, 240)},
#  {'frame': 499,
#   'status': 'GAME_ALIVE',
#   'ball': (22, 223),
#   'ball_speed': (11, 11),
#   'platform_1P': (110, 420),
#   'platform_2P': (105, 50),
#   'blocker': (60, 240)},
#  {'frame': 500,
#   'status': 'GAME_ALIVE',
#   'ball': (33, 234),
#   'ball_speed': (11, 11),
#   'platform_1P': (115, 420),
#   'platform_2P': (105, 50),
#   'blocker': (55, 240)},
#  {'frame': 501,
#   'status': 'GAME_ALIVE',
#   'ball': (45, 246),
#   'ball_speed': (-12, 12),
#   'platform_1P': (120, 420),
#   'platform_2P': (105, 50),
#   'blocker': (50, 240)},
#  {'frame': 502,
#   'status': 'GAME_ALIVE',
#   'ball': (33, 258),
#   'ball_speed': (-12, 12),
#   'platform_1P': (115, 420),
#   'platform_2P': (105, 50),
#   'blocker': (45, 240)},
#  {'frame': 503,
#   'status': 'GAME_ALIVE',
#   'ball': (21, 270),
#   'ball_speed': (-12, 12),
#   'platform_1P': (115, 420),
#   'platform_2P': (105, 50),
#   'blocker': (40, 240)},
#  {'frame': 504,
#   'status': 'GAME_ALIVE',
#   'ball': (9, 282),
#   'ball_speed': (-12, 12),
#   'platform_1P': (115, 420),
#   'platform_2P': (105, 50),
#   'blocker': (35, 240)},
#  {'frame': 505,
#   'status': 'GAME_ALIVE',
#   'ball': (0, 294),
#   'ball_speed': (12, 12),
#   'platform_1P': (115, 420),
#   'platform_2P': (105, 50),
#   'blocker': (30, 240)},
#  {'frame': 506,
#   'status': 'GAME_ALIVE',
#   'ball': (12, 306),
#   'ball_speed': (12, 12),
#   'platform_1P': (115, 420),
#   'platform_2P': (105, 50),
#   'blocker': (25, 240)},
#  {'frame': 507,
#   'status': 'GAME_ALIVE',
#   'ball': (24, 318),
#   'ball_speed': (12, 12),
#   'platform_1P': (115, 420),
#   'platform_2P': (105, 50),
#   'blocker': (20, 240)},
#  {'frame': 508,
#   'status': 'GAME_ALIVE',
#   'ball': (36, 330),
#   'ball_speed': (12, 12),
#   'platform_1P': (115, 420),
#   'platform_2P': (105, 50),
#   'blocker': (15, 240)},
#  {'frame': 509,
#   'status': 'GAME_ALIVE',
#   'ball': (48, 342),
#   'ball_speed': (12, 12),
#   'platform_1P': (115, 420),
#   'platform_2P': (105, 50),
#   'blocker': (10, 240)},
#  {'frame': 510,
#   'status': 'GAME_ALIVE',
#   'ball': (60, 354),
#   'ball_speed': (12, 12),
#   'platform_1P': (115, 420),
#   'platform_2P': (105, 50),
#   'blocker': (5, 240)},
#  {'frame': 511,
#   'status': 'GAME_ALIVE',
#   'ball': (72, 366),
#   'ball_speed': (12, 12),
#   'platform_1P': (115, 420),
#   'platform_2P': (105, 50),
#   'blocker': (0, 240)},
#  {'frame': 512,
#   'status': 'GAME_ALIVE',
#   'ball': (84, 378),
#   'ball_speed': (12, 12),
#   'platform_1P': (115, 420),
#   'platform_2P': (105, 50),
#   'blocker': (5, 240)},
#  {'frame': 513,
#   'status': 'GAME_ALIVE',
#   'ball': (96, 390),
#   'ball_speed': (12, 12),
#   'platform_1P': (115, 420),
#   'platform_2P': (105, 50),
#   'blocker': (10, 240)},
#  {'frame': 514,
#   'status': 'GAME_ALIVE',
#   'ball': (108, 402),
#   'ball_speed': (12, 12),
#   'platform_1P': (115, 420),
#   'platform_2P': (105, 50),
#   'blocker': (15, 240)},
#  {'frame': 515,
#   'status': 'GAME_ALIVE',
#   'ball': (120, 414),
#   'ball_speed': (12, 12),
#   'platform_1P': (115, 420),
#   'platform_2P': (105, 50),
#   'blocker': (20, 240)},
#  {'frame': 516,
#   'status': 'GAME_ALIVE',
#   'ball': (132, 415),
#   'ball_speed': (12, -12),
#   'platform_1P': (115, 420),
#   'platform_2P': (105, 50),
#   'blocker': (25, 240)},
#  {'frame': 517,
#   'status': 'GAME_ALIVE',
#   'ball': (144, 403),
#   'ball_speed': (12, -12),
#   'platform_1P': (115, 420),
#   'platform_2P': (100, 50),
#   'blocker': (30, 240)},
#  {'frame': 518,
#   'status': 'GAME_ALIVE',
#   'ball': (156, 391),
#   'ball_speed': (12, -12),
#   'platform_1P': (115, 420),
#   'platform_2P': (95, 50),
#   'blocker': (35, 240)},
#  {'frame': 519,
#   'status': 'GAME_ALIVE',
#   'ball': (168, 379),
#   'ball_speed': (12, -12),
#   'platform_1P': (115, 420),
#   'platform_2P': (90, 50),
#   'blocker': (40, 240)},
#  {'frame': 520,
#   'status': 'GAME_ALIVE',
#   'ball': (180, 367),
#   'ball_speed': (12, -12),
#   'platform_1P': (115, 420),
#   'platform_2P': (85, 50),
#   'blocker': (45, 240)},
#  {'frame': 521,
#   'status': 'GAME_ALIVE',
#   'ball': (192, 355),
#   'ball_speed': (12, -12),
#   'platform_1P': (115, 420),
#   'platform_2P': (80, 50),
#   'blocker': (50, 240)},
#  {'frame': 522,
#   'status': 'GAME_ALIVE',
#   'ball': (195, 343),
#   'ball_speed': (-12, -12),
#   'platform_1P': (115, 420),
#   'platform_2P': (75, 50),
#   'blocker': (55, 240)},
#  {'frame': 523,
#   'status': 'GAME_ALIVE',
#   'ball': (183, 331),
#   'ball_speed': (-12, -12),
#   'platform_1P': (115, 420),
#   'platform_2P': (70, 50),
#   'blocker': (60, 240)},
#  {'frame': 524,
#   'status': 'GAME_ALIVE',
#   'ball': (171, 319),
#   'ball_speed': (-12, -12),
#   'platform_1P': (115, 420),
#   'platform_2P': (65, 50),
#   'blocker': (65, 240)},
#  {'frame': 525,
#   'status': 'GAME_ALIVE',
#   'ball': (159, 307),
#   'ball_speed': (-12, -12),
#   'platform_1P': (115, 420),
#   'platform_2P': (60, 50),
#   'blocker': (70, 240)},
#  {'frame': 526,
#   'status': 'GAME_ALIVE',
#   'ball': (147, 295),
#   'ball_speed': (-12, -12),
#   'platform_1P': (115, 420),
#   'platform_2P': (55, 50),
#   'blocker': (75, 240)},
#  {'frame': 527,
#   'status': 'GAME_ALIVE',
#   'ball': (135, 283),
#   'ball_speed': (-12, -12),
#   'platform_1P': (115, 420),
#   'platform_2P': (55, 50),
#   'blocker': (80, 240)},
#  {'frame': 528,
#   'status': 'GAME_ALIVE',
#   'ball': (123, 271),
#   'ball_speed': (-12, -12),
#   'platform_1P': (115, 420),
#   'platform_2P': (55, 50),
#   'blocker': (85, 240)},
#  {'frame': 529,
#   'status': 'GAME_ALIVE',
#   'ball': (111, 260),
#   'ball_speed': (-12, 12),
#   'platform_1P': (115, 420),
#   'platform_2P': (55, 50),
#   'blocker': (90, 240)},
#  {'frame': 530,
#   'status': 'GAME_ALIVE',
#   'ball': (99, 272),
#   'ball_speed': (-12, 12),
#   'platform_1P': (110, 420),
#   'platform_2P': (55, 50),
#   'blocker': (95, 240)},
#  {'frame': 531,
#   'status': 'GAME_ALIVE',
#   'ball': (87, 284),
#   'ball_speed': (-12, 12),
#   'platform_1P': (105, 420),
#   'platform_2P': (55, 50),
#   'blocker': (100, 240)},
#  {'frame': 532,
#   'status': 'GAME_ALIVE',
#   'ball': (75, 296),
#   'ball_speed': (-12, 12),
#   'platform_1P': (100, 420),
#   'platform_2P': (55, 50),
#   'blocker': (105, 240)},
#  {'frame': 533,
#   'status': 'GAME_ALIVE',
#   'ball': (63, 308),
#   'ball_speed': (-12, 12),
#   'platform_1P': (95, 420),
#   'platform_2P': (55, 50),
#   'blocker': (110, 240)},
#  {'frame': 534,
#   'status': 'GAME_ALIVE',
#   'ball': (51, 320),
#   'ball_speed': (-12, 12),
#   'platform_1P': (90, 420),
#   'platform_2P': (55, 50),
#   'blocker': (115, 240)},
#  {'frame': 535,
#   'status': 'GAME_ALIVE',
#   'ball': (39, 332),
#   'ball_speed': (-12, 12),
#   'platform_1P': (85, 420),
#   'platform_2P': (55, 50),
#   'blocker': (120, 240)},
#  {'frame': 536,
#   'status': 'GAME_ALIVE',
#   'ball': (27, 344),
#   'ball_speed': (-12, 12),
#   'platform_1P': (80, 420),
#   'platform_2P': (55, 50),
#   'blocker': (125, 240)},
#  {'frame': 537,
#   'status': 'GAME_ALIVE',
#   'ball': (15, 356),
#   'ball_speed': (-12, 12),
#   'platform_1P': (75, 420),
#   'platform_2P': (55, 50),
#   'blocker': (130, 240)},
#  {'frame': 538,
#   'status': 'GAME_ALIVE',
#   'ball': (3, 368),
#   'ball_speed': (-12, 12),
#   'platform_1P': (70, 420),
#   'platform_2P': (55, 50),
#   'blocker': (135, 240)},
#  {'frame': 539,
#   'status': 'GAME_ALIVE',
#   'ball': (0, 380),
#   'ball_speed': (12, 12),
#   'platform_1P': (65, 420),
#   'platform_2P': (55, 50),
#   'blocker': (140, 240)},
#  {'frame': 540,
#   'status': 'GAME_ALIVE',
#   'ball': (12, 392),
#   'ball_speed': (12, 12),
#   'platform_1P': (60, 420),
#   'platform_2P': (55, 50),
#   'blocker': (145, 240)},
#  {'frame': 541,
#   'status': 'GAME_ALIVE',
#   'ball': (24, 404),
#   'ball_speed': (12, 12),
#   'platform_1P': (55, 420),
#   'platform_2P': (55, 50),
#   'blocker': (150, 240)},
#  {'frame': 542,
#   'status': 'GAME_ALIVE',
#   'ball': (36, 416),
#   'ball_speed': (12, 12),
#   'platform_1P': (50, 420),
#   'platform_2P': (55, 50),
#   'blocker': (155, 240)},
#  {'frame': 543,
#   'status': 'GAME_ALIVE',
#   'ball': (40, 428),
#   'ball_speed': (-12, 12),
#   'platform_1P': (45, 420),
#   'platform_2P': (55, 50),
#   'blocker': (160, 240)},
#  {'frame': 544,
#   'status': 'GAME_ALIVE',
#   'ball': (28, 440),
#   'ball_speed': (-12, 12),
#   'platform_1P': (40, 420),
#   'platform_2P': (55, 50),
#   'blocker': (165, 240)},
#  {'frame': 545,
#   'status': 'GAME_2P_WIN',
#   'ball': (16, 452),
#   'ball_speed': (-12, 12),
#   'platform_1P': (35, 420),
#   'platform_2P': (55, 50),
#   'blocker': (170, 240)}]

# %%
    data[i]['ml_1P']['command']
# Out:
# ['SERVE_TO_LEFT',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'MOVE_LEFT',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'MOVE_LEFT',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_RIGHT',
#  'MOVE_LEFT',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'NONE',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  'MOVE_LEFT',
#  None]

# %%
    data[i]['ml_1P']['scene_info'][0], data[i]['ml_1P']['command'][-0]
# Out:
# ({'frame': 0,
#   'status': 'GAME_ALIVE',
#   'ball': (98, 415),
#   'ball_speed': (0, 0),
#   'platform_1P': (80, 420),
#   'platform_2P': (80, 50),
#   'blocker': (180, 240)},
#  'SERVE_TO_LEFT')

# %%
# 提取特徵

scene_info=[]
command=[]
for i in range(0,len(data)):
    scene_info=np.concatenate([scene_info,data[i]['ml_1P']['scene_info']],axis=0)
    command=np.concatenate([command,data[i]['ml_1P']['command']],axis=0)
    

k = range(1, len(scene_info)-1)

ball_x = np.array([scene_info[i]['ball'][0] for i in k])
ball_y = np.array([scene_info[i]['ball'][1] for i in k])
ball_speed_x = np.array([scene_info[i+1]['ball'][0] - scene_info[i]['ball'][0] for i in k])
ball_speed_y = np.array([scene_info[i+1]['ball'][1] - scene_info[i]['ball'][1] for i in k])
direction = np.where(np.vstack((ball_speed_x, ball_speed_y)) > 0, [[1],[0]], [[2],[3]]).sum(axis=0)  # x y: ++1, +-4, -+2, --3
platform = np.array([scene_info[i]['platform_1P'][0] for i in k])
blocker_x=np.array([scene_info[i]['blocker'][0] for i in k])
blocker_speed_x = np.array([scene_info[i+1]['blocker'][0] - scene_info[i]['blocker'][0] for i in k])
            
target = np.where(np.array(command) == 'NONE', 0,
                  np.where(np.array(command) == 'MOVE_LEFT', -1, 1))[1:-1]  # [0] SERVE_TO_RIGHT, [1897] None

# %%
X = np.hstack((ball_x.reshape(-1, 1),
               ball_y.reshape(-1, 1),
               ball_speed_x.reshape(-1, 1),
               ball_speed_y.reshape(-1, 1),
               direction.reshape(-1, 1),
               platform.reshape(-1, 1),
             blocker_x.reshape(-1, 1),
             blocker_speed_x.reshape(-1, 1)))
y=target

# %%
X, y
# Out:
# (array([[ 98, 415,  -7, ...,  80,  25,   5],
#         [ 91, 408,  -7, ...,  80,  30,   5],
#         [ 84, 401,  -7, ...,  80,  35,   5],
#         ...,
#         [ 36, 416,   4, ...,  50, 155,   5],
#         [ 40, 428, -12, ...,  45, 160,   5],
#         [ 28, 440, -12, ...,  40, 165,   5]]),
#  array([ 0,  0,  0, ..., -1, -1, -1]))

# %%
# train data
from sklearn.neighbors import KNeighborsClassifier

model = KNeighborsClassifier()
print(model.fit(X, y))
print(model.score(X, y))
# Out:
# KNeighborsClassifier()
# 0.9796984099043595

# %%
with open('../ml/model.pickle', 'wb') as f:
    pickle.dump(model, f)
